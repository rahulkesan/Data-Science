# %%
import pandas as pd

# %%
import numpy as np

# %%
cp = pd.read_csv(r'C:\Users\RahulK\Downloads\Machine Learning By Pranjal Sir\Regression\Linear\car_price.csv')

# %%
cp.head()
# Out:
#    symboling normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3                 ?       gas  std          two  convertible
# 1          3                 ?       gas  std          two  convertible
# 2          1                 ?       gas  std          two    hatchback
# 3          2               164       gas  std         four        sedan
# 4          2               164       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# ...

# %%
cp.shape
# Out:
# (205, 26)

# %%
cp = cp.replace({'?': np.nan})

# Convert all the'?' to nulls

# %%
cp.head()
# Out:
#    symboling normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3               NaN       gas  std          two  convertible
# 1          3               NaN       gas  std          two  convertible
# 2          1               NaN       gas  std          two    hatchback
# 3          2               164       gas  std         four        sedan
# 4          2               164       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# ...

# %%
cp.isnull().sum()
# Out:
# symboling             0
# normalized_losses    41
# Fuel_type             0
# make                  0
# num_of_doors          2
# aspiration            0
# wheel_base            0
# engine_location       0
# drive_wheels          0
# body_style            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %%
cp.isnull().sum()[cp.isnull().sum() > 0]
# Out:
# normalized_losses    41
# num_of_doors          2
# bore                  4
# stroke                4
# horsepower            2
# peak_rpm              2
# price                 4
# dtype: int64

# %%
cp.normalized_losses.value_counts()
# Out:
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: normalized_losses, dtype: int64

# %%
cp.normalized_losses.mean()

# We will get an error because normalized_losses is an object because it was having '?' and 
# so the entire column has become non-numeric
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [395], in <cell line: 1>()
# ----> 1 cp.normalized_losses.mean()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11117, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11099 @doc(
#   11100     _num_doc,
#   11101     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11115     **kwargs,
#   11116 ):
# > 11117     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10687, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10679 def mean(
#   10680     self,
#   10681     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10685     **kwargs,
#   10686 ) -> Series | float:
# ...

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  164 non-null    object
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       203 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %%
cp.normalized_losses = cp.normalized_losses.astype(float)

# This will convert object into float data type

# %%
cp.normalized_losses.mean()
# Out:
# 122.0

# %%
# Similarly we will do for all the object data that is supposed to be numeric

cp.head()
# Out:
#    symboling  normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3                NaN       gas  std          two  convertible
# 1          3                NaN       gas  std          two  convertible
# 2          1                NaN       gas  std          two    hatchback
# 3          2              164.0       gas  std         four        sedan
# 4          2              164.0       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
cp.head()
# Out:
#    symboling  normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3                NaN       gas  std          two  convertible
# 1          3                NaN       gas  std          two  convertible
# 2          1                NaN       gas  std          two    hatchback
# 3          2              164.0       gas  std         four        sedan
# 4          2              164.0       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# ...

# %%
cp.bore = cp.bore.astype(float)
cp.stroke = cp.stroke.astype(float)
cp.peak_rpm = cp.peak_rpm.astype(float)
cp.horsepower = cp.horsepower.astype(float)
cp.price = cp.price.astype(float)

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  164 non-null    float64
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       203 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %%
cp.isnull().sum()[cp.isnull().sum() > 0]
# Out:
# normalized_losses    41
# num_of_doors          2
# bore                  4
# stroke                4
# horsepower            2
# peak_rpm              2
# price                 4
# dtype: int64

# %%
cp.normalized_losses.fillna(cp.normalized_losses.mean(), inplace= True)
cp.num_of_doors.fillna('four', inplace= True)
cp.bore.fillna(cp.bore.mean(), inplace= True)
cp.stroke.fillna(cp.stroke.mean(), inplace= True)
cp.horsepower.fillna(cp.horsepower.mean(), inplace= True)
cp.peak_rpm.fillna(cp.peak_rpm.mean(), inplace= True)

# We will not fill the nulls value of price column here, because price is the target variable
# And if we will just fill the null value of price with the mean, then there is no point of building the model

# %%
cp.normalized_losses.value_counts()
# Out:
# 122.0    45
# 161.0    11
# 91.0      8
# 150.0     7
# 128.0     6
# 134.0     6
# 104.0     6
# 95.0      5
# 102.0     5
# 103.0     5
# 74.0      5
# 85.0      5
# 65.0      5
# 94.0      5
# 168.0     5
# 106.0     4
# 148.0     4
# 118.0     4
# 93.0      4
# 83.0      3
# 101.0     3
# 115.0     3
# 154.0     3
# 125.0     3
# 137.0     3
# 108.0     2
# 87.0      2
# 119.0     2
# 194.0     2
# 197.0     2
# 89.0      2
# 158.0     2
# 192.0     2
# 113.0     2
# 188.0     2
# 81.0      2
# 110.0     2
# 145.0     2
# 129.0     2
# 164.0     2
# 153.0     2
# 186.0     1
# 107.0     1
# 78.0      1
# 231.0     1
# 77.0      1
# 142.0     1
# 98.0      1
# 121.0     1
# 90.0      1
# 256.0     1
# Name: normalized_losses, dtype: int64

# %%
cp.num_of_doors.value_counts()
# Out:
# four    116
# two      89
# Name: num_of_doors, dtype: int64

# %%
cp.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# Fuel_type            0
# make                 0
# num_of_doors         0
# aspiration           0
# wheel_base           0
# engine_location      0
# drive_wheels         0
# body_style           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                4
# dtype: int64

# %%
# Hence, we will drop the rows where price value is null

cp = cp.dropna()

# %%
cp.shape
# Out:
# (201, 26)

# %%
cp.head()
# Out:
#    symboling  normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3              122.0       gas  std          two  convertible
# 1          3              122.0       gas  std          two  convertible
# 2          1              122.0       gas  std          two    hatchback
# 3          2              164.0       gas  std         four        sedan
# 4          2              164.0       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
cp[cp.select_dtypes(include='object').columns] = cp[cp.select_dtypes(include='object').columns].apply(le.fit_transform)

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   Fuel_type          201 non-null    int32
#  3   make               201 non-null    int32
#  4   num_of_doors       201 non-null    int32
#  5   aspiration         201 non-null    int32
#  6   wheel_base         201 non-null    int32
#  7   engine_location    201 non-null    int32
#  8   drive_wheels       201 non-null    float64
#  9   body_style         201 non-null    int32
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    int32
#  15  num_of_cylinders   201 non-null    int32
# ...

# %%
cp.head()
# Out:
#    symboling  normalized_losses  Fuel_type  make  num_of_doors  aspiration  \
# 0          3              122.0          1     0             1           0
# 1          3              122.0          1     0             1           0
# 2          1              122.0          1     0             1           2
# 3          2              164.0          1     0             0           3
# 4          2              164.0          1     0             0           3
#
#    wheel_base  engine_location  drive_wheels  body_style  length  width  \
# 0           2                0          88.6           0   168.8   64.1
# 1           2                0          88.6           0   168.8   64.1
# 2           2                0          94.5           0   171.2   65.5
# 3           1                0          99.8           1   176.6   66.2
# 4           0                0          99.4           1   176.6   66.4
#
#    height  curb_weight  engine_type  num_of_cylinders  engine_size  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
cp_train, cp_test = train_test_split(cp, test_size=.2)

# %%
cp_train_x = cp_train.iloc[:, 0:-1]
cp_train_y = cp_train.iloc[:, -1]

cp_test_x = cp_test.iloc[:, 0:-1]
cp_test_y = cp_test.iloc[:, -1]

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()

# %%
linreg.fit(cp_train_x, cp_train_y)
# Out:
# LinearRegression()

# %%
Rsquare = linreg.score(cp_train_x,cp_train_y)
Rsquare
# Out:
# 0.8566037486737583

# %%
N = cp_train_x.shape[0]
K = cp_train_x.shape[1]

AdjRsquare = 1 - ((1-Rsquare)*(N-1)/(N-K-1))
AdjRsquare
# Out:
# 0.8274581691359043

# %%
cp_train_pred = linreg.predict(cp_train_x)
cp_test_pred = linreg.predict(cp_test_x)

# %%
error_train = cp_train_y - cp_train_pred
error_test = cp_test_y - cp_test_pred

# %%
error_train.mean()
# Out:
# -1.0743024665237274e-11

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(error_train)
# Out:
# C:\Users\RahulK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
sns.displot(error_train, bins = 25)

# %%
sns.regplot(cp_train_y, cp_train_pred)
# Out:
# C:\Users\RahulK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
plt.plot(error_train, '.')

# %%
MSE = np.mean(np.square(error_test))
MSE
# Out:
# 3250279.5101918923

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 1802.8531582444234

# %%
MAE = np.mean(np.absolute(error_test))
MAE
# Out:
# 1512.283874559782

# %%
MAPE = np.mean(np.absolute(error_test*100/cp_test_y))
MAPE
# Out:
# 14.881944327653933

# %%
l1 = list(cp_train_x.columns)

# %%
l1
# Out:
# ['symboling',
#  'normalized_losses',
#  'Fuel_type',
#  'make',
#  'num_of_doors',
#  'aspiration',
#  'wheel_base',
#  'engine_location',
#  'drive_wheels',
#  'body_style',
#  'length',
#  'width',
#  'height',
#  'curb_weight',
#  'engine_type',
#  'num_of_cylinders',
#  'engine_size',
#  'fuel_system',
#  'bore',
#  'stroke',
#  'compression_ratio',
#  'horsepower',
#  'peak_rpm',
#  'city_mpg',
#  'highway_mpg']

# %%
corr_list = []
for col in l1:
    corr_list.append(cp.price.corr(cp[col]))

# %%
cp.price.corr(cp.engine_size)
# Out:
# 0.8723351674455186

# %%
df = pd.DataFrame()
df['Column'] = l1
df['Corr'] = corr_list

# %%
df
# Out:
#                Column      Corr
# 0           symboling -0.082391
# 1   normalized_losses  0.133999
# 2           Fuel_type -0.110326
# 3                make  0.179578
# 4        num_of_doors -0.042435
# 5          aspiration -0.072933
# 6          wheel_base  0.588333
# 7     engine_location  0.331062
# 8        drive_wheels  0.584642
# 9          body_style -0.163646
# 10             length  0.690628
# 11              width  0.751265
# 12             height  0.135486
# 13        curb_weight  0.834415
# 14        engine_type  0.126025
# 15   num_of_cylinders  0.005509
# 16        engine_size  0.872335
# 17        fuel_system  0.521689
# 18               bore  0.543155
# 19             stroke  0.082269
# 20  compression_ratio  0.071107
# 21         horsepower  0.809575
# 22           peak_rpm -0.101616
# 23           city_mpg -0.686571
# 24        highway_mpg -0.704692

# %%
df[(df.Corr > 0.5) | (df.Corr < -0.5)]
# Out:
#           Column      Corr
# 6     wheel_base  0.588333
# 8   drive_wheels  0.584642
# 10        length  0.690628
# 11         width  0.751265
# 13   curb_weight  0.834415
# 16   engine_size  0.872335
# 17   fuel_system  0.521689
# 18          bore  0.543155
# 21    horsepower  0.809575
# 23      city_mpg -0.686571
# 24   highway_mpg -0.704692

# %%
df1 = df[(df.Corr > 0.07) | (df.Corr < -0.07)]

# %%
df1
# Out:
#                Column      Corr
# 0           symboling -0.082391
# 1   normalized_losses  0.133999
# 2           Fuel_type -0.110326
# 3                make  0.179578
# 5          aspiration -0.072933
# 6          wheel_base  0.588333
# 7     engine_location  0.331062
# 8        drive_wheels  0.584642
# 9          body_style -0.163646
# 10             length  0.690628
# 11              width  0.751265
# 12             height  0.135486
# 13        curb_weight  0.834415
# 14        engine_type  0.126025
# 16        engine_size  0.872335
# 17        fuel_system  0.521689
# 18               bore  0.543155
# 19             stroke  0.082269
# 20  compression_ratio  0.071107
# 21         horsepower  0.809575
# 22           peak_rpm -0.101616
# 23           city_mpg -0.686571
# 24        highway_mpg -0.704692

# %%
l2 = list(df1.Column)
l2
# Out:
# ['symboling',
#  'normalized_losses',
#  'Fuel_type',
#  'make',
#  'aspiration',
#  'wheel_base',
#  'engine_location',
#  'drive_wheels',
#  'body_style',
#  'length',
#  'width',
#  'height',
#  'curb_weight',
#  'engine_type',
#  'engine_size',
#  'fuel_system',
#  'bore',
#  'stroke',
#  'compression_ratio',
#  'horsepower',
#  'peak_rpm',
#  'city_mpg',
#  'highway_mpg']

# %%
l2.append('price')

# %%
cp = cp_filter

# %%
cp = cp.loc[:, l2]

# %%
# 25 = .896/.877
# 11 = .83
# 12 = .84/.823
# 19 = .890/.875
# 23 = .897/.880
# 21 = .884/.866

# %%
cp = cp_filter

# %%
cp.shape
# Out:
# (201, 24)

# %%
cp_filter = cp

# %%
cp.head()
# Out:
#    symboling  normalized_losses  Fuel_type  make  num_of_doors  aspiration  \
# 0          3              122.0          1     0             1           0
# 1          3              122.0          1     0             1           0
# 2          1              122.0          1     0             1           2
# 3          2              164.0          1     0             0           3
# 4          2              164.0          1     0             0           3
#
#    wheel_base  engine_location  drive_wheels  body_style  length  width  \
# 0           2                0          88.6           0   168.8   64.1
# 1           2                0          88.6           0   168.8   64.1
# 2           2                0          94.5           0   171.2   65.5
# 3           1                0          99.8           1   176.6   66.2
# 4           0                0          99.4           1   176.6   66.4
#
#    height  curb_weight  engine_type  num_of_cylinders  engine_size  \
# ...

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized_losses  201 non-null    float64
#  1   Fuel_type          201 non-null    object
#  2   make               201 non-null    object
#  3   wheel_base         201 non-null    object
#  4   engine_location    201 non-null    object
#  5   drive_wheels       201 non-null    float64
#  6   body_style         201 non-null    object
#  7   length             201 non-null    float64
#  8   width              201 non-null    float64
#  9   height             201 non-null    float64
#  10  curb_weight        201 non-null    int64
#  11  engine_type        201 non-null    object
#  12  engine_size        201 non-null    int64
#  13  fuel_system        201 non-null    object
#  14  bore               201 non-null    float64
#  15  horsepower         201 non-null    float64
# ...

# %%
# Hence, with 23 x-variables we get the maximum value for Rsquare and AdjRsquare
l2
# Out:
# ['symboling',
#  'normalized_losses',
#  'Fuel_type',
#  'make',
#  'aspiration',
#  'wheel_base',
#  'engine_location',
#  'drive_wheels',
#  'body_style',
#  'length',
#  'width',
#  'height',
#  'curb_weight',
#  'engine_type',
#  'engine_size',
#  'fuel_system',
#  'bore',
#  'stroke',
#  'compression_ratio',
#  'horsepower',
#  'peak_rpm',
#  'city_mpg',
#  'highway_mpg',
#  'price']

# %%
def remove_outliers(a,col,k):
    mean = a[col].mean()
    sd = a[col].std()
    global a1
    final_list = [x for x in a[col] if (x > mean - k*sd)]
    final_list = [x for x in final_list if (x < mean + k*sd)]
    a1 = a.loc[a[col].isin(final_list)] ; print(a1.shape)
    print("Number of outliers removed == >" , a.shape[0] - a1.shape[0])

# %%
remove_outliers(cp, 'price', 2)
# Out:
# (187, 26)
# Number of outliers removed == > 14

# %%
cp = a1

# %%
cp_filter.shape
# Out:
# (201, 26)

# %%
cp.shape
# Out:
# (187, 26)
